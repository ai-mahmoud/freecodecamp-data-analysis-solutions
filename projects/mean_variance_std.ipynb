# %%
import numpy as np
def mean_var_std(something):
    X = np.array(something).reshape((3,3))
    result = {
    'mean': [X.mean(axis=0).tolist(), X.mean(axis=1).tolist(), X.mean().tolist()],
    'variance': [X.var(axis=0).tolist(), X.var(axis=1).tolist(), X.var().tolist()],
    'std': [X.std(axis=0).tolist(), X.std(axis=1).tolist(), X.std().tolist()],
    'max': [X.max(axis=0).tolist(), X.max(axis=1).tolist(), X.max().tolist()],
    'min': [X.min(axis=0).tolist(), X.min(axis=1).tolist(), X.min().tolist()],
    'sum': [X.sum(axis=0).tolist(), X.sum(axis=1).tolist(), X.sum().tolist()]
    }
    return result

# %%
mean_var_std([0,1,2,3,4,5,6,7,8])
# Out:
# {'mean': [[3.0, 4.0, 5.0], [1.0, 4.0, 7.0], 4.0],
#  'variance': [[6.0, 6.0, 6.0],
#   [0.6666666666666666, 0.6666666666666666, 0.6666666666666666],
#   6.666666666666667],
#  'std': [[2.449489742783178, 2.449489742783178, 2.449489742783178],
#   [0.816496580927726, 0.816496580927726, 0.816496580927726],
#   2.581988897471611],
#  'max': [[6, 7, 8], [2, 5, 8], 8],
#  'min': [[0, 1, 2], [0, 3, 6], 0],
#  'sum': [[9, 12, 15], [3, 12, 21], 36]}
